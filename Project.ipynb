# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Load area mappings

# %%
area_df = pd.read_table("ap_area.txt")
#remove spaces in column headers
area_df.columns = area_df.columns.str.replace(' ','')

area_df
# Out:
#    area_code                             area_name
# 0       0000                     U.S. city average
# 1       0100                             Northeast
# 2       0110                           New England
# 3       0120                       Middle Atlantic
# 4       0200                               Midwest
# ..       ...                                   ...
# 69      S49C  Riverside-San Bernardino-Ontario, CA
# 70      S49D            Seattle-Tacoma-Bellevue WA
# 71      S49E                San Diego-Carlsbad, CA
# 72      S49F                          Urban Hawaii
# 73      S49G                          Urban Alaska
#
# [74 rows x 2 columns]

# %% [markdown]
# ## create dates df

# %%
dates_df = pd.DataFrame(pd.date_range('1980-01-01','2022-08-01', freq='MS'), columns=['report_date'])

dates_df['year'] = dates_df['report_date'].dt.year
dates_df['month'] = dates_df['report_date'].dt.month
dates_df['day'] = dates_df['report_date'].dt.day

dates_df
# Out:
#     report_date  year  month  day
# 0    1980-01-01  1980      1    1
# 1    1980-02-01  1980      2    1
# 2    1980-03-01  1980      3    1
# 3    1980-04-01  1980      4    1
# 4    1980-05-01  1980      5    1
# ..          ...   ...    ...  ...
# 507  2022-04-01  2022      4    1
# 508  2022-05-01  2022      5    1
# 509  2022-06-01  2022      6    1
# 510  2022-07-01  2022      7    1
# 511  2022-08-01  2022      8    1
#
# [512 rows x 4 columns]

# %% [markdown]
# ## Load food series values

# %%
# pull in data
food_df = pd.read_table("ap_data_3_Food.txt", low_memory = False)

# remove spaces in column headers
food_df.columns = food_df.columns.str.replace(' ','')

# remove white space from column values
food_df['series_id'] = food_df['series_id'].str.strip()

# get year month dat
food_df['year'] = food_df['year'].astype(int)
food_df['month'] = food_df.period.str[1:].astype(int)
food_df['day'] = 1

# convert to date
food_df["report_date"] = pd.to_datetime(food_df[['year', 'month', 'day']])

# create new price column
food_df['price'] = food_df['value'].str.strip().str.replace('-', 'nan').fillna(0).astype(float)

# get rid of these
food_df.drop(columns=['footnote_codes', 'period', 'value'], inplace=True)

# create full series, date mapping
food_full_dates_df = pd.merge(pd.DataFrame(food_df['series_id'].unique().tolist(), columns=['series_id']), dates_df, how='cross')


# rejoin so we have all months per series
food_df = pd.merge(food_full_dates_df, food_df, on=['series_id', 'report_date', 'year', 'month', 'day'], how='left')

# forward fill our prices so that we can avoid nulls on yoy growth / percent difference
food_df = food_df.sort_values(by=['series_id', 'report_date', 'year', 'month', 'day']).fillna(method="ffill")

# %%
# food_df[food_df.year.eq(2020) & food_df.series_id.eq('APU0000712311')]
food_df
# Out:
#             series_id report_date  year  month  day  price
# 0       APU0000701111  1980-01-01  1980      1    1  0.203
# 1       APU0000701111  1980-02-01  1980      2    1  0.205
# 2       APU0000701111  1980-03-01  1980      3    1  0.211
# 3       APU0000701111  1980-04-01  1980      4    1  0.206
# 4       APU0000701111  1980-05-01  1980      5    1  0.207
# ...               ...         ...   ...    ...  ...    ...
# 344059  APU0400FS1101  2022-04-01  2022      4    1  4.529
# 344060  APU0400FS1101  2022-05-01  2022      5    1  4.529
# 344061  APU0400FS1101  2022-06-01  2022      6    1  4.590
# 344062  APU0400FS1101  2022-07-01  2022      7    1  4.616
# 344063  APU0400FS1101  2022-08-01  2022      8    1  4.834
#
# [344064 rows x 6 columns]

# %% [markdown]
# ## Load series mappings

# %%
series_df = pd.read_table("ap_series.txt")

# remove whitespace from column names
series_df.columns = series_df.columns.str.replace(' ','')

# remove whitespace from column values
series_strip_cols = ['series_id', 'series_title', 'area_code', 'item_code']
series_df[series_strip_cols] = series_df[series_strip_cols].apply(lambda x: x.str.strip())

# convert to int
series_df[['begin_year', 'end_year']] = series_df[['begin_year', 'end_year']].astype(int)
series_df['begin_month'] = series_df.begin_period.str[1:].astype(int)
series_df['end_month'] = series_df.end_period.str[1:].astype(int)

series_df.drop(columns=['footnote_codes', 'begin_period', 'end_period'], inplace=True)
    
series_df
# Out:
#           series_id area_code item_code  \
# 0     APU0000701111      0000    701111
# 1     APU0000701311      0000    701311
# 2     APU0000701312      0000    701312
# 3     APU0000701321      0000    701321
# 4     APU0000701322      0000    701322
# ...             ...       ...       ...
# 1477   APUS49G74713      S49G     74713
# 1478   APUS49G74714      S49G     74714
# 1479   APUS49G74715      S49G     74715
# 1480   APUS49G74716      S49G     74716
# 1481   APUS49G7471A      S49G     7471A
#
#                                            series_title  begin_year  end_year  \
# 0     Flour, white, all purpose, per lb. (453.6 gm) ...        1980      2022
# 1     Rice, white, long grain, precooked (cost per p...        1980      1981
# 2     Rice, white, long grain, uncooked, per lb. (45...        1980      2022
# 3     Spaghetti (cost per pound/453.6 grams) in U.S....        1980      1981
# 4     Spaghetti and macaroni, per lb. (453.6 gm) in ...        1984      2022
# ...                                                 ...         ...       ...
# 1477  Gasoline, leaded premium (cost per gallon/3.8 ...        1978      1981
# 1478  Gasoline, unleaded regular, per gallon/3.785 l...        1978      2022
# 1479  Gasoline, unleaded midgrade, per gallon/3.785 ...        2021      2022
# 1480  Gasoline, unleaded premium, per gallon/3.785 l...        1981      2022
# 1481  Gasoline, all types, per gallon/3.785 liters i...        1978      2022
#
#       begin_month  end_month
# 0               1          8
# 1               1         12
# 2               1          8
# 3               1          3
# 4               1          8
# ...           ...        ...
# 1477            1          4
# 1478            1          8
# 1479            6          8
# 1480            9          8
# 1481            1          8
#
# [1482 rows x 8 columns]

# %% [markdown]
# ## Load item mappings

# %%
item_df = pd.read_table("ap_item.txt")


# remove whitespace from column names
item_df.columns = item_df.columns.str.replace(' ','')

# remove whitespace from column values
item_strip_cols = ['item_name', 'item_code']
item_df[item_strip_cols] = item_df[item_strip_cols].apply(lambda x: x.str.strip())


item_df
# Out:
#     item_code                                          item_name
# 0      701111      Flour, white, all purpose, per lb. (453.6 gm)
# 1      701311  Rice, white, long grain, precooked (cost per p...
# 2      701312  Rice, white, long grain, uncooked, per lb. (45...
# 3      701321             Spaghetti (cost per pound/453.6 grams)
# 4      701322         Spaghetti and macaroni, per lb. (453.6 gm)
# ..        ...                                                ...
# 155    FJ4101                       Yogurt, per 8 oz. (226.8 gm)
# 156    FL2101               Lettuce, romaine, per lb. (453.6 gm)
# 157    FN1101            All soft drinks, per 2 liters (67.6 oz)
# 158    FN1102  All soft drinks, 12 pk, 12 oz., cans, per 12 o...
# 159    FS1101                  Butter, stick, per lb. (453.6 gm)
#
# [160 rows x 2 columns]

# %% [markdown]
# ## Merge datasets

# %%
df = food_df.merge(series_df, how = "left", on = "series_id") \
          .merge(item_df, how="left", on="item_code") \
          .merge(area_df, how = "left", on = "area_code")
df
# Out:
#             series_id report_date  year  month  day  price area_code  \
# 0       APU0000701111  1980-01-01  1980      1    1  0.203      0000
# 1       APU0000701111  1980-02-01  1980      2    1  0.205      0000
# 2       APU0000701111  1980-03-01  1980      3    1  0.211      0000
# 3       APU0000701111  1980-04-01  1980      4    1  0.206      0000
# 4       APU0000701111  1980-05-01  1980      5    1  0.207      0000
# ...               ...         ...   ...    ...  ...    ...       ...
# 344059  APU0400FS1101  2022-04-01  2022      4    1  4.529      0400
# 344060  APU0400FS1101  2022-05-01  2022      5    1  4.529      0400
# 344061  APU0400FS1101  2022-06-01  2022      6    1  4.590      0400
# 344062  APU0400FS1101  2022-07-01  2022      7    1  4.616      0400
# 344063  APU0400FS1101  2022-08-01  2022      8    1  4.834      0400
#
#        item_code                                       series_title  \
# 0         701111  Flour, white, all purpose, per lb. (453.6 gm) ...
# 1         701111  Flour, white, all purpose, per lb. (453.6 gm) ...
# 2         701111  Flour, white, all purpose, per lb. (453.6 gm) ...
# 3         701111  Flour, white, all purpose, per lb. (453.6 gm) ...
# 4         701111  Flour, white, all purpose, per lb. (453.6 gm) ...
# ...          ...                                                ...
# 344059    FS1101  Butter, stick, per lb. (453.6 gm) in West, ave...
# 344060    FS1101  Butter, stick, per lb. (453.6 gm) in West, ave...
# 344061    FS1101  Butter, stick, per lb. (453.6 gm) in West, ave...
# 344062    FS1101  Butter, stick, per lb. (453.6 gm) in West, ave...
# 344063    FS1101  Butter, stick, per lb. (453.6 gm) in West, ave...
#
#         begin_year  end_year  begin_month  end_month  \
# 0             1980      2022            1          8
# 1             1980      2022            1          8
# 2             1980      2022            1          8
# 3             1980      2022            1          8
# 4             1980      2022            1          8
# ...            ...       ...          ...        ...
# 344059        2018      2022            4          8
# 344060        2018      2022            4          8
# 344061        2018      2022            4          8
# 344062        2018      2022            4          8
# 344063        2018      2022            4          8
#
#                                             item_name          area_name
# 0       Flour, white, all purpose, per lb. (453.6 gm)  U.S. city average
# 1       Flour, white, all purpose, per lb. (453.6 gm)  U.S. city average
# 2       Flour, white, all purpose, per lb. (453.6 gm)  U.S. city average
# 3       Flour, white, all purpose, per lb. (453.6 gm)  U.S. city average
# 4       Flour, white, all purpose, per lb. (453.6 gm)  U.S. city average
# ...                                               ...                ...
# 344059              Butter, stick, per lb. (453.6 gm)               West
# 344060              Butter, stick, per lb. (453.6 gm)               West
# 344061              Butter, stick, per lb. (453.6 gm)               West
# 344062              Butter, stick, per lb. (453.6 gm)               West
# 344063              Butter, stick, per lb. (453.6 gm)               West
#
# [344064 rows x 15 columns]

# %% [markdown]
# # Process Data

# %% [markdown]
# #### Filter merged dataset to include data from last 20 years where we have a full range of values (ie data from 2002 to 2022 M08)

# %%
##filter to only include data for last twenty years, where we have a fuller set of information for that series
df_filtered = df[df.begin_year.lt(2002) & 
                 df.end_year.eq(2022) &
                 df.end_month.eq(8) &
                 df.year.ge(2002)
                ]
df_filtered
# Out:
#             series_id report_date  year  month  day  price area_code  \
# 264     APU0000701111  2002-01-01  2002      1    1  0.319      0000
# 265     APU0000701111  2002-02-01  2002      2    1  0.318      0000
# 266     APU0000701111  2002-03-01  2002      3    1  0.310      0000
# 267     APU0000701111  2002-04-01  2002      4    1  0.307      0000
# 268     APU0000701111  2002-05-01  2002      5    1  0.323      0000
# ...               ...         ...   ...    ...  ...    ...       ...
# 340475  APU0400FD4101  2022-04-01  2022      4    1  3.859      0400
# 340476  APU0400FD4101  2022-05-01  2022      5    1  3.860      0400
# 340477  APU0400FD4101  2022-06-01  2022      6    1  4.037      0400
# 340478  APU0400FD4101  2022-07-01  2022      7    1  3.765      0400
# 340479  APU0400FD4101  2022-08-01  2022      8    1  3.659      0400
#
#        item_code                                       series_title  \
# 264       701111  Flour, white, all purpose, per lb. (453.6 gm) ...
# 265       701111  Flour, white, all purpose, per lb. (453.6 gm) ...
# 266       701111  Flour, white, all purpose, per lb. (453.6 gm) ...
# 267       701111  Flour, white, all purpose, per lb. (453.6 gm) ...
# 268       701111  Flour, white, all purpose, per lb. (453.6 gm) ...
# ...          ...                                                ...
# 340475    FD4101  All Other Pork (Excluding Canned Ham and Lunch...
# 340476    FD4101  All Other Pork (Excluding Canned Ham and Lunch...
# 340477    FD4101  All Other Pork (Excluding Canned Ham and Lunch...
# 340478    FD4101  All Other Pork (Excluding Canned Ham and Lunch...
# 340479    FD4101  All Other Pork (Excluding Canned Ham and Lunch...
#
#         begin_year  end_year  begin_month  end_month  \
# 264           1980      2022            1          8
# 265           1980      2022            1          8
# 266           1980      2022            1          8
# 267           1980      2022            1          8
# 268           1980      2022            1          8
# ...            ...       ...          ...        ...
# 340475        1998      2022            1          8
# 340476        1998      2022            1          8
# 340477        1998      2022            1          8
# 340478        1998      2022            1          8
# 340479        1998      2022            1          8
#
#                                                 item_name          area_name
# 264         Flour, white, all purpose, per lb. (453.6 gm)  U.S. city average
# 265         Flour, white, all purpose, per lb. (453.6 gm)  U.S. city average
# 266         Flour, white, all purpose, per lb. (453.6 gm)  U.S. city average
# 267         Flour, white, all purpose, per lb. (453.6 gm)  U.S. city average
# 268         Flour, white, all purpose, per lb. (453.6 gm)  U.S. city average
# ...                                                   ...                ...
# 340475  All Other Pork (Excluding Canned Ham and Lunch...               West
# 340476  All Other Pork (Excluding Canned Ham and Lunch...               West
# 340477  All Other Pork (Excluding Canned Ham and Lunch...               West
# 340478  All Other Pork (Excluding Canned Ham and Lunch...               West
# 340479  All Other Pork (Excluding Canned Ham and Lunch...               West
#
# [43152 rows x 15 columns]

# %% [markdown]
# #### Filter merged dataset to exclude items that don't exist for all geographies so we're looking at a consistent set of items

# %%
record_count_by_item_area = (pd.DataFrame({'count' : df_filtered.groupby( [ "area_name", "item_name"] ).size()})
                                         .reset_index()
                                         .pivot(index="item_name", columns="area_name", values="count")
                                         .dropna(axis=0)
                                         .reset_index()
                            )

items_for_analysis = record_count_by_item_area["item_name"].unique().tolist()
items_for_analysis
# Out:
# ['All Ham (Excluding Canned Ham and Luncheon Slices), per lb. (453.6 gm)',
#  'All Other Pork (Excluding Canned Ham and Luncheon Slices), per lb. (453.6 gm)',
#  'All Pork Chops, per lb. (453.6 gm)',
#  'All Uncooked Beef Roasts, per lb. (453.6 gm)',
#  'All Uncooked Beef Steaks, per lb. (453.6 gm)',
#  'All Uncooked Other Beef (Excluding Veal), per lb. (453.6 gm)',
#  'All uncooked ground beef, per lb. (453.6 gm)',
#  'Bacon, sliced, per lb. (453.6 gm)',
#  'Bananas, per lb. (453.6 gm)',
#  'Bread, white, pan, per lb. (453.6 gm)',
#  'Cheddar cheese, natural, per lb. (453.6 gm)',
#  'Chicken, fresh, whole, per lb. (453.6 gm)',
#  'Chops, boneless, per lb. (453.6 gm)',
#  'Ground beef, 100% beef, per lb. (453.6 gm)',
#  'Ice cream, prepackaged, bulk, regular, per 1/2 gal. (1.9 lit)',
#  'Malt beverages, all types, all sizes, any origin, per 16 oz. (473.2 ml)',
#  'Potato chips, per 16 oz.',
#  'Potatoes, white, per lb. (453.6 gm)',
#  'Spaghetti and macaroni, per lb. (453.6 gm)',
#  'Steak, sirloin, USDA Choice, boneless, per lb. (453.6 gm)',
#  'Tomatoes, field grown, per lb. (453.6 gm)',
#  'Wine, red and white table, all sizes, any origin, per 1 liter (33.8 oz)']

# %% [markdown]
# ## Clean up

# %%
# filter
final_df = df_filtered[df_filtered["item_name"].isin(items_for_analysis)].copy()

# # rename to fit pd.to_datetime reqs
# final_df.rename(columns={'value': 'price', 
#                          'period_num': 'month', 
#                          'day_num': 'day'}, inplace=True)

# # create date
# final_df["report_date"] = pd.to_datetime(final_df[['year', 'month', 'day']])

# clean up dtypes:
# final_df['price'] = final_df['price'].astype('double')
# final_df['month'] = final_df['month'].astype('int')


# sort and forward fill so that we only have null prices at the beginning 
# (sets to last month's price if null)
# final_df = final_df.sort_values(by=['area_name', 'item_name', 'year', 'month']).fillna(method="ffill")

# %% [markdown]
# ## Create Categorical Variables

# %%
# parse item names for category key words
item_category_conditions = [
final_df['item_name'].str.lower().str.contains('ham|steak|beef|chicken|bacon|pork|boneless'),
final_df['item_name'].str.lower().str.contains('tomatoes|potatoes|bananas'),
final_df['item_name'].str.lower().str.contains('wine|malt'),
final_df['item_name'].str.lower().str.contains('ice cream|cheese'),
final_df['item_name'].str.lower().str.contains('bread|spaghetti'),
final_df['item_name'].str.lower().str.contains('chips')
]

# assign labels
item_category_labels = ['Meat', 'Produce', 'Alcohol', 'Dairy', 'Grains', 'Snacks']

# create the column
final_df['category'] = np.select(item_category_conditions, item_category_labels)

# %%
final_df[final_df.category.eq('Dairy')][['item_name', 'category']]
# final_df[final_df.category.eq('0')][['item_name', 'category']]
# Out:
#                                                 item_name category
# 33544         Cheddar cheese, natural, per lb. (453.6 gm)    Dairy
# 33545         Cheddar cheese, natural, per lb. (453.6 gm)    Dairy
# 33546         Cheddar cheese, natural, per lb. (453.6 gm)    Dairy
# 33547         Cheddar cheese, natural, per lb. (453.6 gm)    Dairy
# 33548         Cheddar cheese, natural, per lb. (453.6 gm)    Dairy
# ...                                                   ...      ...
# 306683  Ice cream, prepackaged, bulk, regular, per 1/2...    Dairy
# 306684  Ice cream, prepackaged, bulk, regular, per 1/2...    Dairy
# 306685  Ice cream, prepackaged, bulk, regular, per 1/2...    Dairy
# 306686  Ice cream, prepackaged, bulk, regular, per 1/2...    Dairy
# 306687  Ice cream, prepackaged, bulk, regular, per 1/2...    Dairy
#
# [2480 rows x 2 columns]

# %% [markdown]
# ## Calculate Values

# %% [markdown]
# ### 12 month rolling average w/ YoY price change

# %%
final_df.dtypes
# Out:
# series_id               object
# report_date     datetime64[ns]
# year                     int64
# month                    int64
# day                      int64
# price                  float64
# area_code               object
# item_code               object
# series_title            object
# begin_year               int64
# end_year                 int64
# begin_month              int64
# end_month                int64
# item_name               object
# area_name               object
# category                object
# dtype: object

# %%
# get price for area, item at same time last year:
final_df['12mo_ma_price'] = final_df.sort_values(by=['year','month'], ascending=True) \
                                            .groupby(['area_name', 'item_name'])['price'].transform(lambda x: x.rolling(12, 1).mean())


# get price for area, item at same time last year:
final_df['ly_12mo_ma_price'] = final_df.sort_values(by=['month', 'year'], ascending=True) \
                                .groupby(['area_name', 'item_name'])['12mo_ma_price'].shift(1)



# calculate price change, absolute and percent change
final_df['yoy_12mo_ma_price_change'] = (final_df['12mo_ma_price'] - final_df['ly_12mo_ma_price'])
final_df['yoy_12mo_ma_price_percent_change'] =  round(100 * final_df['yoy_12mo_ma_price_change'] / final_df['ly_12mo_ma_price'], 2)

# %%
# get price for area, item at same time last year:
final_df['ly_price'] = final_df.sort_values(by=['month', 'year'], ascending=True) \
                                .groupby(['area_name', 'item_name'])['price'].shift(1)


# calculate price change, absolute and percent change
final_df['yoy_price_change'] = (final_df['price'] - final_df['ly_price'])
final_df['yoy_price_percent_change'] =  round(100 * final_df['yoy_price_change'] / final_df['ly_price'], 2)

# %% [markdown]
# ### prove & show

# %%
# show that the above works  & final_df.month.eq(4)
final_df[final_df.area_name.eq('U.S. city average') & 
         final_df.item_name.str.contains('Tomatoes') &
         final_df.month.isin([2])] \
        [['series_id', 'area_name', 'item_name', 
          'month', 'year', '12mo_ma_price', 'ly_12mo_ma_price', 
          'yoy_price_change', 'yoy_price_percent_change']].style
# Out:
# <style type="text/css">
# </style>
# <table id="T_d57ac_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >series_id</th>
#       <th class="col_heading level0 col1" >area_name</th>
#       <th class="col_heading level0 col2" >item_name</th>
#       <th class="col_heading level0 col3" >month</th>
#       <th class="col_heading level0 col4" >year</th>
#       <th class="col_heading level0 col5" >12mo_ma_price</th>
#       <th class="col_heading level0 col6" >ly_12mo_ma_price</th>
#       <th class="col_heading level0 col7" >yoy_price_change</th>
#       <th class="col_heading level0 col8" >yoy_price_percent_change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d57ac_level0_row0" class="row_heading level0 row0" >42249</th>
#       <td id="T_d57ac_row0_col0" class="data row0 col0" >APU0000712311</td>
#       <td id="T_d57ac_row0_col1" class="data row0 col1" >U.S. city average</td>
#       <td id="T_d57ac_row0_col2" class="data row0 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_d57ac_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_d57ac_row0_col4" class="data row0 col4" >2002</td>
#       <td id="T_d57ac_row0_col5" class="data row0 col5" >1.374500</td>
#       <td id="T_d57ac_row0_col6" class="data row0 col6" >1.846083</td>
#       <td id="T_d57ac_row0_col7" class="data row0 col7" >-0.594000</td>
#       <td id="T_d57ac_row0_col8" class="data row0 col8" >-31.400000</td>
#     </tr>
#     <tr>
#       <th id="T_d57ac_level0_row1" class="row_heading level0 row1" >42261</th>
#       <td id="T_d57ac_row1_col0" class="data row1 col0" >APU0000712311</td>
#       <td id="T_d57ac_row1_col1" class="data row1 col1" >U.S. city average</td>
#       <td id="T_d57ac_row1_col2" class="data row1 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_d57ac_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_d57ac_row1_col4" class="data row1 col4" >2003</td>
#       <td id="T_d57ac_row1_col5" class="data row1 col5" >1.368417</td>
#       <td id="T_d57ac_row1_col6" class="data row1 col6" >1.374500</td>
#       <td id="T_d57ac_row1_col7" class="data row1 col7" >0.267000</td>
#       <td id="T_d57ac_row1_col8" class="data row1 col8" >20.570000</td>
#     </tr>
#     <tr>
#       <th id="T_d57ac_level0_row2" class="row_heading level0 row2" >42273</th>
#       <td id="T_d57ac_row2_col0" class="data row2 col0" >APU0000712311</td>
#       <td id="T_d57ac_row2_col1" class="data row2 col1" >U.S. city average</td>
#       <td id="T_d57ac_row2_col2" class="data row2 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_d57ac_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_d57ac_row2_col4" class="data row2 col4" >2004</td>
#       <td id="T_d57ac_row2_col5" class="data row2 col5" >1.484583</td>
#       <td id="T_d57ac_row2_col6" class="data row2 col6" >1.368417</td>
#       <td id="T_d57ac_row2_col7" class="data row2 col7" >-0.055000</td>
#       <td id="T_d57ac_row2_col8" class="data row2 col8" >-3.510000</td>
#     </tr>
#     <tr>
#       <th id="T_d57ac_level0_row3" class="row_heading level0 row3" >42285</th>
#       <td id="T_d57ac_row3_col0" class="data row3 col0" >APU0000712311</td>
#       <td id="T_d57ac_row3_col1" class="data row3 col1" >U.S. city average</td>
#       <td id="T_d57ac_row3_col2" class="data row3 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_d57ac_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_d57ac_row3_col4" class="data row3 col4" >2005</td>
#       <td id="T_d57ac_row3_col5" class="data row3 col5" >1.615167</td>
#       <td id="T_d57ac_row3_col6" class="data row3 col6" >1.484583</td>
#       <td id="T_d57ac_row3_col7" class="data row3 col7" >-0.082000</td>
#       <td id="T_d57ac_row3_col8" class="data row3 col8" >-5.430000</td>
#     </tr>
#     <tr>
#       <th id="T_d57ac_level0_row4" class="row_heading level0 row4" >42297</th>
#       <td id="T_d57ac_row4_col0" class="data row4 col0" >APU0000712311</td>
#       <td id="T_d57ac_row4_col1" class="data row4 col1" >U.S. city average</td>
#       <td id="T_d57ac_row4_col2" class="data row4 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_d57ac_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_d57ac_row4_col4" class="data row4 col4" >2006</td>
#       <td id="T_d57ac_row4_col5" class="data row4 col5" >1.693083</td>
#       <td id="T_d57ac_row4_col6" class="data row4 col6" >1.615167</td>
#       <td id="T_d57ac_row4_col7" class="data row4 col7" >0.482000</td>
#       <td id="T_d57ac_row4_col8" class="data row4 col8" >33.750000</td>
#     </tr>
#     <tr>
#       <th id="T_d57ac_level0_row5" class="row_heading level0 row5" >42309</th>
#       <td id="T_d57ac_row5_col0" class="data row5 col0" >APU0000712311</td>
#       <td id="T_d57ac_row5_col1" class="data row5 col1" >U.S. city average</td>
#       <td id="T_d57ac_row5_col2" class="data row5 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_d57ac_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_d57ac_row5_col4" class="data row5 col4" >2007</td>
#       <td id="T_d57ac_row5_col5" class="data row5 col5" >1.664417</td>
#       <td id="T_d57ac_row5_col6" class="data row5 col6" >1.693083</td>
#       <td id="T_d57ac_row5_col7" class="data row5 col7" >-0.266000</td>
#       <td id="T_d57ac_row5_col8" class="data row5 col8" >-13.930000</td>
#     </tr>
#     <tr>
#       <th id="T_d57ac_level0_row6" class="row_heading level0 row6" >42321</th>
#       <td id="T_d57ac_row6_col0" class="data row6 col0" >APU0000712311</td>
#       <td id="T_d57ac_row6_col1" class="data row6 col1" >U.S. city average</td>
#       <td id="T_d57ac_row6_col2" class="data row6 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_d57ac_row6_col3" class="data row6 col3" >2</td>
#       <td id="T_d57ac_row6_col4" class="data row6 col4" >2008</td>
#       <td id="T_d57ac_row6_col5" class="data row6 col5" >1.688417</td>
#       <td id="T_d57ac_row6_col6" class="data row6 col6" >1.664417</td>
#       <td id="T_d57ac_row6_col7" class="data row6 col7" >0.091000</td>
#       <td id="T_d57ac_row6_col8" class="data row6 col8" >5.540000</td>
#     </tr>
#     <tr>
#       <th id="T_d57ac_level0_row7" class="row_heading level0 row7" >42333</th>
#       <td id="T_d57ac_row7_col0" class="data row7 col0" >APU0000712311</td>
#       <td id="T_d57ac_row7_col1" class="data row7 col1" >U.S. city average</td>
#       <td id="T_d57ac_row7_col2" class="data row7 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_d57ac_row7_col3" class="data row7 col3" >2</td>
#       <td id="T_d57ac_row7_col4" class="data row7 col4" >2009</td>
#       <td id="T_d57ac_row7_col5" class="data row7 col5" >1.698250</td>
#       <td id="T_d57ac_row7_col6" class="data row7 col6" >1.688417</td>
#       <td id="T_d57ac_row7_col7" class="data row7 col7" >-0.179000</td>
#       <td id="T_d57ac_row7_col8" class="data row7 col8" >-10.320000</td>
#     </tr>
#     <tr>
#       <th id="T_d57ac_level0_row8" class="row_heading level0 row8" >42345</th>
#       <td id="T_d57ac_row8_col0" class="data row8 col0" >APU0000712311</td>
#       <td id="T_d57ac_row8_col1" class="data row8 col1" >U.S. city average</td>
#       <td id="T_d57ac_row8_col2" class="data row8 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_d57ac_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_d57ac_row8_col4" class="data row8 col4" >2010</td>
#       <td id="T_d57ac_row8_col5" class="data row8 col5" >1.654833</td>
#       <td id="T_d57ac_row8_col6" class="data row8 col6" >1.698250</td>
#       <td id="T_d57ac_row8_col7" class="data row8 col7" >0.209000</td>
#       <td id="T_d57ac_row8_col8" class="data row8 col8" >13.430000</td>
#     </tr>
#     <tr>
#       <th id="T_d57ac_level0_row9" class="row_heading level0 row9" >42357</th>
#       <td id="T_d57ac_row9_col0" class="data row9 col0" >APU0000712311</td>
#       <td id="T_d57ac_row9_col1" class="data row9 col1" >U.S. city average</td>
#       <td id="T_d57ac_row9_col2" class="data row9 col2" >Tomatoes, field grown, per lb.

# %%
# show that the above works  & final_df.month.eq(4)
final_df[final_df.area_name.eq('U.S. city average') & 
         final_df.item_name.str.contains('Tomatoes') &
         final_df.year.eq(2012)] \
        [['series_id', 'area_name', 'item_name', 
          'month', 'year', 'price', 'ly_price', 
          'yoy_price_change', 'yoy_price_percent_change']].style
# Out:
# <style type="text/css">
# </style>
# <table id="T_7b026_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >series_id</th>
#       <th class="col_heading level0 col1" >area_name</th>
#       <th class="col_heading level0 col2" >item_name</th>
#       <th class="col_heading level0 col3" >month</th>
#       <th class="col_heading level0 col4" >year</th>
#       <th class="col_heading level0 col5" >price</th>
#       <th class="col_heading level0 col6" >ly_price</th>
#       <th class="col_heading level0 col7" >yoy_price_change</th>
#       <th class="col_heading level0 col8" >yoy_price_percent_change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b026_level0_row0" class="row_heading level0 row0" >42368</th>
#       <td id="T_7b026_row0_col0" class="data row0 col0" >APU0000712311</td>
#       <td id="T_7b026_row0_col1" class="data row0 col1" >U.S. city average</td>
#       <td id="T_7b026_row0_col2" class="data row0 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_7b026_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_7b026_row0_col4" class="data row0 col4" >2012</td>
#       <td id="T_7b026_row0_col5" class="data row0 col5" >1.542000</td>
#       <td id="T_7b026_row0_col6" class="data row0 col6" >1.590000</td>
#       <td id="T_7b026_row0_col7" class="data row0 col7" >-0.048000</td>
#       <td id="T_7b026_row0_col8" class="data row0 col8" >-3.020000</td>
#     </tr>
#     <tr>
#       <th id="T_7b026_level0_row1" class="row_heading level0 row1" >42369</th>
#       <td id="T_7b026_row1_col0" class="data row1 col0" >APU0000712311</td>
#       <td id="T_7b026_row1_col1" class="data row1 col1" >U.S. city average</td>
#       <td id="T_7b026_row1_col2" class="data row1 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_7b026_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_7b026_row1_col4" class="data row1 col4" >2012</td>
#       <td id="T_7b026_row1_col5" class="data row1 col5" >1.433000</td>
#       <td id="T_7b026_row1_col6" class="data row1 col6" >1.832000</td>
#       <td id="T_7b026_row1_col7" class="data row1 col7" >-0.399000</td>
#       <td id="T_7b026_row1_col8" class="data row1 col8" >-21.780000</td>
#     </tr>
#     <tr>
#       <th id="T_7b026_level0_row2" class="row_heading level0 row2" >42370</th>
#       <td id="T_7b026_row2_col0" class="data row2 col0" >APU0000712311</td>
#       <td id="T_7b026_row2_col1" class="data row2 col1" >U.S. city average</td>
#       <td id="T_7b026_row2_col2" class="data row2 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_7b026_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_7b026_row2_col4" class="data row2 col4" >2012</td>
#       <td id="T_7b026_row2_col5" class="data row2 col5" >1.452000</td>
#       <td id="T_7b026_row2_col6" class="data row2 col6" >2.086000</td>
#       <td id="T_7b026_row2_col7" class="data row2 col7" >-0.634000</td>
#       <td id="T_7b026_row2_col8" class="data row2 col8" >-30.390000</td>
#     </tr>
#     <tr>
#       <th id="T_7b026_level0_row3" class="row_heading level0 row3" >42371</th>
#       <td id="T_7b026_row3_col0" class="data row3 col0" >APU0000712311</td>
#       <td id="T_7b026_row3_col1" class="data row3 col1" >U.S. city average</td>
#       <td id="T_7b026_row3_col2" class="data row3 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_7b026_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_7b026_row3_col4" class="data row3 col4" >2012</td>
#       <td id="T_7b026_row3_col5" class="data row3 col5" >1.388000</td>
#       <td id="T_7b026_row3_col6" class="data row3 col6" >2.270000</td>
#       <td id="T_7b026_row3_col7" class="data row3 col7" >-0.882000</td>
#       <td id="T_7b026_row3_col8" class="data row3 col8" >-38.850000</td>
#     </tr>
#     <tr>
#       <th id="T_7b026_level0_row4" class="row_heading level0 row4" >42372</th>
#       <td id="T_7b026_row4_col0" class="data row4 col0" >APU0000712311</td>
#       <td id="T_7b026_row4_col1" class="data row4 col1" >U.S. city average</td>
#       <td id="T_7b026_row4_col2" class="data row4 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_7b026_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_7b026_row4_col4" class="data row4 col4" >2012</td>
#       <td id="T_7b026_row4_col5" class="data row4 col5" >1.336000</td>
#       <td id="T_7b026_row4_col6" class="data row4 col6" >1.794000</td>
#       <td id="T_7b026_row4_col7" class="data row4 col7" >-0.458000</td>
#       <td id="T_7b026_row4_col8" class="data row4 col8" >-25.530000</td>
#     </tr>
#     <tr>
#       <th id="T_7b026_level0_row5" class="row_heading level0 row5" >42373</th>
#       <td id="T_7b026_row5_col0" class="data row5 col0" >APU0000712311</td>
#       <td id="T_7b026_row5_col1" class="data row5 col1" >U.S. city average</td>
#       <td id="T_7b026_row5_col2" class="data row5 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_7b026_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_7b026_row5_col4" class="data row5 col4" >2012</td>
#       <td id="T_7b026_row5_col5" class="data row5 col5" >1.492000</td>
#       <td id="T_7b026_row5_col6" class="data row5 col6" >1.559000</td>
#       <td id="T_7b026_row5_col7" class="data row5 col7" >-0.067000</td>
#       <td id="T_7b026_row5_col8" class="data row5 col8" >-4.300000</td>
#     </tr>
#     <tr>
#       <th id="T_7b026_level0_row6" class="row_heading level0 row6" >42374</th>
#       <td id="T_7b026_row6_col0" class="data row6 col0" >APU0000712311</td>
#       <td id="T_7b026_row6_col1" class="data row6 col1" >U.S. city average</td>
#       <td id="T_7b026_row6_col2" class="data row6 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_7b026_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_7b026_row6_col4" class="data row6 col4" >2012</td>
#       <td id="T_7b026_row6_col5" class="data row6 col5" >1.506000</td>
#       <td id="T_7b026_row6_col6" class="data row6 col6" >1.442000</td>
#       <td id="T_7b026_row6_col7" class="data row6 col7" >0.064000</td>
#       <td id="T_7b026_row6_col8" class="data row6 col8" >4.440000</td>
#     </tr>
#     <tr>
#       <th id="T_7b026_level0_row7" class="row_heading level0 row7" >42375</th>
#       <td id="T_7b026_row7_col0" class="data row7 col0" >APU0000712311</td>
#       <td id="T_7b026_row7_col1" class="data row7 col1" >U.S. city average</td>
#       <td id="T_7b026_row7_col2" class="data row7 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_7b026_row7_col3" class="data row7 col3" >8</td>
#       <td id="T_7b026_row7_col4" class="data row7 col4" >2012</td>
#       <td id="T_7b026_row7_col5" class="data row7 col5" >1.440000</td>
#       <td id="T_7b026_row7_col6" class="data row7 col6" >1.420000</td>
#       <td id="T_7b026_row7_col7" class="data row7 col7" >0.020000</td>
#       <td id="T_7b026_row7_col8" class="data row7 col8" >1.410000</td>
#     </tr>
#     <tr>
#       <th id="T_7b026_level0_row8" class="row_heading level0 row8" >42376</th>
#       <td id="T_7b026_row8_col0" class="data row8 col0" >APU0000712311</td>
#       <td id="T_7b026_row8_col1" class="data row8 col1" >U.S. city average</td>
#       <td id="T_7b026_row8_col2" class="data row8 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td>
#       <td id="T_7b026_row8_col3" class="data row8 col3" >9</td>
#       <td id="T_7b026_row8_col4" class="data row8 col4" >2012</td>
#       <td id="T_7b026_row8_col5" class="data row8 col5" >1.384000</td>
#       <td id="T_7b026_row8_col6" class="data row8 col6" >1.503000</td>
#       <td id="T_7b026_row8_col7" class="data row8 col7" >-0.119000</td>
#       <td id="T_7b026_row8_col8" class="data row8 col8" >-7.920000</td>
#     </tr>
#     <tr>
#       <th id="T_7b026_level0_row9" class="row_heading level0 row9" >42377</th>
#       <td id="T_7b026_row9_col0" class="data row9 col0" >APU0000712311</td>
#       <td id="T_7b026_row9_col1" class="data row9 col1" >U.S. city average</td>
#       <td id="T_7b026_row9_col2" class="data row9 col2" >Tomatoes, field grown, per lb. (453.6 gm)</td

# %%
# show that the above works  & final_df.month.eq(4)
final_df[final_df.area_name.eq('U.S. city average') & 
         final_df.item_name.str.contains('Tomatoes') & 
         final_df.year.eq(2020)]
# Out:
#            series_id report_date  year  month  day  price area_code item_code  \
# 42464  APU0000712311  2020-01-01  2020      1    1  2.221      0000    712311
# 42465  APU0000712311  2020-02-01  2020      2    1  2.197      0000    712311
# 42466  APU0000712311  2020-03-01  2020      3    1  2.197      0000    712311
# 42467  APU0000712311  2020-04-01  2020      4    1  2.197      0000    712311
# 42468  APU0000712311  2020-05-01  2020      5    1  1.851      0000    712311
# 42469  APU0000712311  2020-06-01  2020      6    1  1.922      0000    712311
# 42470  APU0000712311  2020-07-01  2020      7    1  1.977      0000    712311
# 42471  APU0000712311  2020-08-01  2020      8    1  1.874      0000    712311
# 42472  APU0000712311  2020-09-01  2020      9    1  1.847      0000    712311
# 42473  APU0000712311  2020-10-01  2020     10    1  1.911      0000    712311
# 42474  APU0000712311  2020-11-01  2020     11    1  1.935      0000    712311
# 42475  APU0000712311  2020-12-01  2020     12    1  1.893      0000    712311
#
#                                             series_title  begin_year  ...  \
# 42464  Tomatoes, field grown, per lb. (453.6 gm) in U...        1980  ...
# 42465  Tomatoes, field grown, per lb. (453.6 gm) in U...        1980  ...
# 42466  Tomatoes, field grown, per lb. (453.6 gm) in U...        1980  ...
# 42467  Tomatoes, field grown, per lb. (453.6 gm) in U...        1980  ...
# 42468  Tomatoes, field grown, per lb. (453.6 gm) in U...        1980  ...
# 42469  Tomatoes, field grown, per lb. (453.6 gm) in U...        1980  ...
# 42470  Tomatoes, field grown, per lb. (453.6 gm) in U...        1980  ...
# 42471  Tomatoes, field grown, per lb. (453.6 gm) in U...        1980  ...
# 42472  Tomatoes, field grown, per lb. (453.6 gm) in U...        1980  ...
# 42473  Tomatoes, field grown, per lb. (453.6 gm) in U...        1980  ...
# 42474  Tomatoes, field grown, per lb. (453.6 gm) in U...        1980  ...
# 42475  Tomatoes, field grown, per lb. (453.6 gm) in U...        1980  ...
#
#                                        item_name          area_name  category  \
# 42464  Tomatoes, field grown, per lb. (453.6 gm)  U.S. city average   Produce
# 42465  Tomatoes, field grown, per lb. (453.6 gm)  U.S. city average   Produce
# 42466  Tomatoes, field grown, per lb. (453.6 gm)  U.S. city average   Produce
# 42467  Tomatoes, field grown, per lb. (453.6 gm)  U.S. city average   Produce
# 42468  Tomatoes, field grown, per lb. (453.6 gm)  U.S. city average   Produce
# 42469  Tomatoes, field grown, per lb. (453.6 gm)  U.S. city average   Produce
# 42470  Tomatoes, field grown, per lb. (453.6 gm)  U.S. city average   Produce
# 42471  Tomatoes, field grown, per lb. (453.6 gm)  U.S. city average   Produce
# 42472  Tomatoes, field grown, per lb. (453.6 gm)  U.S. city average   Produce
# 42473  Tomatoes, field grown, per lb. (453.6 gm)  U.S. city average   Produce
# 42474  Tomatoes, field grown, per lb. (453.6 gm)  U.S. city average   Produce
# 42475  Tomatoes, field grown, per lb. (453.6 gm)  U.S. city average   Produce
#
#       12mo_ma_price ly_12mo_ma_price yoy_12mo_ma_price_change  \
# 42464      1.930000         1.907250                 0.022750
# 42465      1.940750         1.910750                 0.030000
# 42466      1.950583         1.928333                 0.022250
# 42467      1.971417         1.940417                 0.031000
# 42468      1.973750         1.952750                 0.021000
# 42469      1.982917         1.961583                 0.021333
# 42470      1.997750         1.954250                 0.043500
# 42471      1.998583         1.964833                 0.033750
# 42472      1.993250         1.971917                 0.021333
# 42473      2.004250         1.961750                 0.042500
# 42474      2.006917         1.948917                 0.058000
# 42475      2.001833         1.930500                 0.071333
#
#        yoy_12mo_ma_price_percent_change  ly_price  yoy_price_change  \
# 42464                              1.19     2.227            -0.006
# 42465                              1.57     2.068             0.129
# 42466                              1.15     2.079             0.118
# 42467                              1.60     1.947             0.250
# 42468                              1.08     1.823             0.028
# 42469                              1.09     1.812             0.110
# 42470                              2.23     1.799             0.178
# 42471                              1.72     1.864             0.010
# 42472                              1.08     1.911            -0.064
# 42473                              2.17     1.779             0.132
# 42474                              2.98     1.903             0.032
# 42475                              3.70     1.954            -0.061
#
#        yoy_price_percent_change
# 42464                     -0.27
# 42465                      6.24
# 42466                      5.68
# 42467                     12.84
# 42468                      1.54
# 42469                      6.07
# 42470                      9.89
# 42471                      0.54
# 42472                     -3.35
# 42473                      7.42
# 42474                      1.68
# 42475                     -3.12
#
# [12 rows x 23 columns]

# %% [markdown]
# # ***Write Data***

# %%
#write final data to csv
final_df.to_csv("output_cpi_data.csv")
final_df
# Out:
#             series_id report_date  year  month  day  price area_code  \
# 2312    APU0000701322  2002-01-01  2002      1    1  0.912      0000
# 2313    APU0000701322  2002-02-01  2002      2    1  0.902      0000
# 2314    APU0000701322  2002-03-01  2002      3    1  0.917      0000
# 2315    APU0000701322  2002-04-01  2002      4    1  0.927      0000
# 2316    APU0000701322  2002-05-01  2002      5    1  0.901      0000
# ...               ...         ...   ...    ...  ...    ...       ...
# 340475  APU0400FD4101  2022-04-01  2022      4    1  3.859      0400
# 340476  APU0400FD4101  2022-05-01  2022      5    1  3.860      0400
# 340477  APU0400FD4101  2022-06-01  2022      6    1  4.037      0400
# 340478  APU0400FD4101  2022-07-01  2022      7    1  3.765      0400
# 340479  APU0400FD4101  2022-08-01  2022      8    1  3.659      0400
#
#        item_code                                       series_title  \
# 2312      701322  Spaghetti and macaroni, per lb. (453.6 gm) in ...
# 2313      701322  Spaghetti and macaroni, per lb. (453.6 gm) in ...
# 2314      701322  Spaghetti and macaroni, per lb. (453.6 gm) in ...
# 2315      701322  Spaghetti and macaroni, per lb. (453.6 gm) in ...
# 2316      701322  Spaghetti and macaroni, per lb. (453.6 gm) in ...
# ...          ...                                                ...
# 340475    FD4101  All Other Pork (Excluding Canned Ham and Lunch...
# 340476    FD4101  All Other Pork (Excluding Canned Ham and Lunch...
# 340477    FD4101  All Other Pork (Excluding Canned Ham and Lunch...
# 340478    FD4101  All Other Pork (Excluding Canned Ham and Lunch...
# 340479    FD4101  All Other Pork (Excluding Canned Ham and Lunch...
#
#         begin_year  ...                                          item_name  \
# 2312          1984  ...         Spaghetti and macaroni, per lb. (453.6 gm)
# 2313          1984  ...         Spaghetti and macaroni, per lb. (453.6 gm)
# 2314          1984  ...         Spaghetti and macaroni, per lb. (453.6 gm)
# 2315          1984  ...         Spaghetti and macaroni, per lb. (453.6 gm)
# 2316          1984  ...         Spaghetti and macaroni, per lb. (453.6 gm)
# ...            ...  ...                                                ...
# 340475        1998  ...  All Other Pork (Excluding Canned Ham and Lunch...
# 340476        1998  ...  All Other Pork (Excluding Canned Ham and Lunch...
# 340477        1998  ...  All Other Pork (Excluding Canned Ham and Lunch...
# 340478        1998  ...  All Other Pork (Excluding Canned Ham and Lunch...
# 340479        1998  ...  All Other Pork (Excluding Canned Ham and Lunch...
#
#                 area_name  category 12mo_ma_price ly_12mo_ma_price  \
# 2312    U.S. city average    Grains      0.912000              NaN
# 2313    U.S. city average    Grains      0.907000         1.162750
# 2314    U.S. city average    Grains      0.910333         1.148083
# 2315    U.S. city average    Grains      0.914500         1.134833
# 2316    U.S. city average    Grains      0.911800         1.132000
# ...                   ...       ...           ...              ...
# 340475               West      Meat      3.749750         3.147500
# 340476               West      Meat      3.778833         3.200083
# 340477               West      Meat      3.802250         3.221750
# 340478               West      Meat      3.798500         3.264167
# 340479               West      Meat      3.792000         3.297083
#
#        yoy_12mo_ma_price_change  yoy_12mo_ma_price_percent_change  ly_price  \
# 2312                        NaN                               NaN       NaN
# 2313                  -0.255750                            -22.00     1.116
# 2314                  -0.237750                            -20.71     1.148
# 2315                  -0.220333                            -19.42     1.182
# 2316                  -0.220200                            -19.45     1.217
# ...                         ...                               ...       ...
# 340475                 0.602250                             19.13     3.320
# 340476                 0.578750                             18.09     3.511
# 340477                 0.580500                             18.02     3.756
# 340478                 0.534333                             16.37     3.810
# 340479                 0.494917                             15.01     3.737
#
#         yoy_price_change  yoy_price_percent_change
# 2312                 NaN                       NaN
# 2313              -0.214                    -19.18
# 2314              -0.231                    -20.12
# 2315              -0.255                    -21.57
# 2316              -0.316                    -25.97
# ...                  ...                       ...
# 340475             0.539                     16.23
# 340476             0.349                      9.94
# 340477             0.281                      7.48
# 340478            -0.045                     -1.18
# 340479            -0.078                     -2.09
#
# [27280 rows x 23 columns]
